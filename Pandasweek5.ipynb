# %%
import pandas as pd
import numpy as np
print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.4
# 1.20.3

# %%
rows1 = 365*24
cols1 = 2
cols_a = ['Col1', 'Col2']
df = pd.DataFrame(np.random.randint(1, 20, size=(rows1, cols1)), columns=cols_a)
df.index = pd.util.testing.makeDateIndex(rows1, freq='H')
df
# Out:
# C:\Users\Rosi Rachel\anaconda3\lib\site-packages\pandas\util\__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                      Col1  Col2
# 2000-01-01 00:00:00     7     9
# 2000-01-01 01:00:00     7    13
# 2000-01-01 02:00:00     5     3
# 2000-01-01 03:00:00    14     7
# 2000-01-01 04:00:00     7     5
# ...                   ...   ...
# 2000-12-30 19:00:00     5     6
# 2000-12-30 20:00:00     9    19
# 2000-12-30 21:00:00     2     2
# 2000-12-30 22:00:00     8     9
# 2000-12-30 23:00:00     8     2
#
# [8760 rows x 2 columns]

# %%
df.resample('M')['Col1'].sum().to_frame()
# Out:
#             Col1
# 2000-01-31  7416
# 2000-02-29  7142
# 2000-03-31  7261
# 2000-04-30  7010
# 2000-05-31  7407
# 2000-06-30  7109
# 2000-07-31  7338
# 2000-08-31  7520
# 2000-09-30  7365
# 2000-10-31  7280
# 2000-11-30  7349
# 2000-12-31  6947

# %%
df.resample('D')['Col1'].sum().to_frame()
# Out:
#             Col1
# 2000-01-01   214
# 2000-01-02   270
# 2000-01-03   269
# 2000-01-04   273
# 2000-01-05   218
# ...          ...
# 2000-12-26   240
# 2000-12-27   210
# 2000-12-28   236
# 2000-12-29   210
# 2000-12-30   209
#
# [365 rows x 1 columns]

# %%
pd.DataFrame({'col1':[1, 2, 3, 4], 'col2':[5, 6, 7, 8]})
# Out:
#    col1  col2
# 0     1     5
# 1     2     6
# 2     3     7
# 3     4     8

# %%
rows2 = 5
cols2 = 3
arr = np.random.randint(1, 20, size=(rows2, cols2))
arr
# Out:
# array([[10, 12,  5],
#        [18, 14, 11],
#        [10,  6,  6],
#        [ 3, 10, 19],
#        [10,  6, 16]])

# %%
pd.DataFrame(arr, columns=tuple('ABC'))
# Out:
#     A   B   C
# 0  10  12   5
# 1  18  14  11
# 2  10   6   6
# 3   3  10  19
# 4  10   6  16

# %%
pd.util.testing.makeDataFrame().head()
# Out:
#                    A         B         C         D
# 71G6oVU7XM  0.855463 -0.094222  0.260862 -0.271138
# CaaSUntAZq  0.302732 -2.196944  0.900990 -2.499120
# ZbP6KzbFli -1.572842 -1.005147 -0.021180  0.279707
# YrcKLRHedt  0.391507 -1.259721  0.617141 -0.381494
# VBKiSLOqV0  0.198970 -2.081467  1.308470 -1.027030

# %%
pd.util.testing.makeMixedDataFrame().head()
# Out:
#      A    B     C          D
# 0  0.0  0.0  foo1 2009-01-01
# 1  1.0  1.0  foo2 2009-01-02
# 2  2.0  0.0  foo3 2009-01-05
# 3  3.0  1.0  foo4 2009-01-06
# 4  4.0  0.0  foo5 2009-01-07

# %%
pd.util.testing.makeTimeDataFrame().head()
# Out:
#                    A         B         C         D
# 2000-01-03  0.491570 -0.285554  1.118318 -0.482435
# 2000-01-04 -0.129820  0.226705  1.099776  0.240425
# 2000-01-05 -0.424545  0.626161 -0.825069  1.148184
# 2000-01-06 -0.658214 -0.250325  1.188269  1.191449
# 2000-01-07 -0.122575  0.797837 -0.214827  3.012783

# %%
pd.util.testing.makeMissingDataframe().head()
# Out:
#                    A         B         C         D
# JhQcuIxIav -0.982205 -1.657055  0.882496 -1.335846
# QLVHoUoCB5 -1.089145 -0.035030  0.767497       NaN
# jUpJBtLJKb  1.367440 -1.117897  0.301691  0.285161
# Fy43h4dFzH -0.238722       NaN -2.572553  0.152141
# TIMcc7yOqe       NaN -0.909068  1.130876  0.725233

# %%
rows3 = 5
cols3 = 2
cols_b = ['Omset', 'Operasional']
df = pd.DataFrame(np.random.randint(1, 20, size=(rows3, cols3)), columns=cols_b)
df
# Out:
#    Omset  Operasional
# 0      1           14
# 1     12            5
# 2     11           19
# 3     10            5
# 4      7            5

# %%
df['Omset'] = df['Omset']*100_000
df['Operasional'] = df['Operasional']*10_000
df
# Out:
#      Omset  Operasional
# 0   100000       140000
# 1  1200000        50000
# 2  1100000       190000
# 3  1000000        50000
# 4   700000        50000

# %%
df.index = pd.util.testing.makeDateIndex(rows3, freq='D')
df = df.reset_index()
df = df.rename(columns={'index':'tanggal'})
df
# Out:
#      tanggal    Omset  Operasional
# 0 2000-01-01   100000       140000
# 1 2000-01-02  1200000        50000
# 2 2000-01-03  1100000       190000
# 3 2000-01-04  1000000        50000
# 4 2000-01-05   700000        50000

# %%
formatku = {'tanggal':'{:%d/%m/%y}', 'Operasional':'Rp {:.2f}', 'Omset':'Rp {:.2f}'}
laporan = df.style.format(formatku)
laporan
# Out:
# <style type="text/css">
# </style>
# <table id="T_500e3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >Omset</th>
#       <th class="col_heading level0 col2" >Operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_500e3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_500e3_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_500e3_row0_col1" class="data row0 col1" >Rp 100000.00</td>
#       <td id="T_500e3_row0_col2" class="data row0 col2" >Rp 140000.00</td>
#     </tr>
#     <tr>
#       <th id="T_500e3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_500e3_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_500e3_row1_col1" class="data row1 col1" >Rp 1200000.00</td>
#       <td id="T_500e3_row1_col2" class="data row1 col2" >Rp 50000.00</td>
#     </tr>
# ...

# %%
type(laporan)
# Out:
# pandas.io.formats.style.Styler

# %%
laporan.hide_index()
# Out:
# <style type="text/css">
# </style>
# <table id="T_500e3_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >Omset</th>
#       <th class="col_heading level0 col2" >Operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_500e3_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_500e3_row0_col1" class="data row0 col1" >Rp 100000.00</td>
#       <td id="T_500e3_row0_col2" class="data row0 col2" >Rp 140000.00</td>
#     </tr>
#     <tr>
#       <td id="T_500e3_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_500e3_row1_col1" class="data row1 col1" >Rp 1200000.00</td>
#       <td id="T_500e3_row1_col2" class="data row1 col2" >Rp 50000.00</td>
#     </tr>
#     <tr>
#       <td id="T_500e3_row2_col0" class="data row2 col0" >03/01/00</td>
#       <td id="T_500e3_row2_col1" class="data row2 col1" >Rp 1100000.00</td>
# ...

# %%
laporan.set_caption('Data Omset dan Operasional')
# Out:
# <style type="text/css">
# </style>
# <table id="T_500e3_">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >Omset</th>
#       <th class="col_heading level0 col2" >Operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_500e3_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_500e3_row0_col1" class="data row0 col1" >Rp 100000.00</td>
#       <td id="T_500e3_row0_col2" class="data row0 col2" >Rp 140000.00</td>
#     </tr>
#     <tr>
#       <td id="T_500e3_row1_col0" class="data row1 col0" >02/01/00</td>
#       <td id="T_500e3_row1_col1" class="data row1 col1" >Rp 1200000.00</td>
#       <td id="T_500e3_row1_col2" class="data row1 col2" >Rp 50000.00</td>
#     </tr>
#     <tr>
#       <td id="T_500e3_row2_col0" class="data row2 col0" >03/01/00</td>
# ...

# %%
laporan.highlight_min('Omset', color='pink')
laporan.highlight_max('Omset', color='lightgreen')

laporan.highlight_min('Operasional', color='lightblue')
laporan.highlight_max('Operasional', color='grey')
# Out:
# <style type="text/css">
# #T_500e3_row0_col1 {
#   background-color: pink;
# }
# #T_500e3_row1_col1 {
#   background-color: lightgreen;
# }
# #T_500e3_row1_col2, #T_500e3_row3_col2, #T_500e3_row4_col2 {
#   background-color: lightblue;
# }
# #T_500e3_row2_col2 {
#   background-color: grey;
# }
# </style>
# <table id="T_500e3_">
#   <caption>Data Omset dan Operasional</caption>
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >tanggal</th>
#       <th class="col_heading level0 col1" >Omset</th>
#       <th class="col_heading level0 col2" >Operasional</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_500e3_row0_col0" class="data row0 col0" >01/01/00</td>
#       <td id="T_500e3_row0_col1" class="data row0 col1" >Rp 100000.00</td>
#       <td id="T_500e3_row0_col2" class="data row0 col2" >Rp 140000.00</td>
#     </tr>
#     <tr>
#       <td id="T_500e3_row1_col0" class="data row1 col0" >02/01/00</td>
# ...

# %%
d1 = {'col1':[1, 2, 3], 'col2':[10, 20, 30]}
df1 = pd.DataFrame(d1)
df1
# Out:
#    col1  col2
# 0     1    10
# 1     2    20
# 2     3    30

# %%
d2 = {'col3':[4, 5, 6], 'col4':[40, 50, 60]}
df2 = pd.DataFrame(d2)
df2
# Out:
#    col3  col4
# 0     4    40
# 1     5    50
# 2     6    60

# %%
df = pd.merge(df1, df2, left_index=True, right_index=True)
df
# Out:
#    col1  col2  col3  col4
# 0     1    10     4    40
# 1     2    20     5    50
# 2     3    30     6    60

# %%
import pandas as pd
import numpy as np

print(pd.__version__)
print(np.__version__)
# Out:
# 1.3.4
# 1.20.3

# %%
n_rows = 5
n_cols = 5
cols = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 10, size=(n_rows, n_cols)), columns=cols)
df
# Out:
#    A  B  C  D  E
# 0  5  4  7  5  9
# 1  1  5  3  4  9
# 2  4  7  3  5  2
# 3  8  8  5  5  3
# 4  8  8  4  4  1

# %%
tuple('ABCDE')
# Out:
# ('A', 'B', 'C', 'D', 'E')

# %%
df.add_prefix('Kolom_')
# Out:
#    Kolom_A  Kolom_B  Kolom_C  Kolom_D  Kolom_E
# 0        5        4        7        5        9
# 1        1        5        3        4        9
# 2        4        7        3        5        2
# 3        8        8        5        5        3
# 4        8        8        4        4        1

# %%
df.add_suffix('_field')
# Out:
#    A_field  B_field  C_field  D_field  E_field
# 0        5        4        7        5        9
# 1        1        5        3        4        9
# 2        4        7        3        5        2
# 3        8        8        5        5        3
# 4        8        8        4        4        1

# %%
m_rows = 10
m_cols = 5
cols_1 = tuple('ABCDE')

df = pd.DataFrame(np.random.randint(1, 5, size=(m_rows, m_cols)), columns=cols_1)
df
# Out:
#    A  B  C  D  E
# 0  2  2  2  1  1
# 1  3  1  4  4  4
# 2  3  4  4  1  3
# 3  4  1  1  1  2
# 4  2  4  3  3  2
# 5  3  1  1  3  2
# 6  2  1  1  3  1
# 7  4  4  2  2  1
# 8  4  1  4  1  1
# 9  2  2  1  4  4

# %%
df[(df['A'] == 1) | (df['A'] == 3)]
# Out:
#    A  B  C  D  E
# 1  3  1  4  4  4
# 2  3  4  4  1  3
# 5  3  1  1  3  2

# %%
df[df['A'].isin([1,3])]
# Out:
#    A  B  C  D  E
# 1  3  1  4  4  4
# 2  3  4  4  1  3
# 5  3  1  1  3  2

# %%
df[~df['A'].isin([1,3])]
# Out:
#    A  B  C  D  E
# 0  2  2  2  1  1
# 3  4  1  1  1  2
# 4  2  4  3  3  2
# 6  2  1  1  3  1
# 7  4  4  2  2  1
# 8  4  1  4  1  1
# 9  2  2  1  4  4

# %%
data = {'col1':['1', '2', '3', 'kata'], 'col2':['1', '2', '3', '4']}
df = pd.DataFrame(data)
df
# Out:
#    col1 col2
# 0     1    1
# 1     2    2
# 2     3    3
# 3  kata    4

# %%
df.dtypes
# Out:
# col1    object
# col2    object
# dtype: object

# %%
df_x = df.astype({'col2':'int'})
df_x
# Out:
#    col1  col2
# 0     1     1
# 1     2     2
# 2     3     3
# 3  kata     4

# %%
df_x.dtypes
# Out:
# col1    object
# col2     int32
# dtype: object

# %%
df_y = df.astype({'col2':'float'})
df_y
# Out:
#    col1  col2
# 0     1   1.0
# 1     2   2.0
# 2     3   3.0
# 3  kata   4.0

# %%
df_y.dtypes
# Out:
# col1     object
# col2    float64
# dtype: object

# %%
df.apply(pd.to_numeric, errors='coerce')
# Out:
#    col1  col2
# 0   1.0     1
# 1   2.0     2
# 2   3.0     3
# 3   NaN     4

# %%
o_rows = 5
o_cols = 2
cols_2 = ['bil_pecahan', 'bil_bulat']
df = pd.DataFrame(np.random.randint(1, 20, size=(o_rows, o_cols)), columns=cols_2)
df['bil_pecahan'] = df['bil_pecahan'].astype('float')
df.index = pd.util.testing.makeDateIndex(o_rows, freq='H')
df = df.reset_index()
df['teks'] = list('ABCDE')
df
# Out:
# C:\Users\Rosi Rachel\anaconda3\lib\site-packages\pandas\util\__init__.py:15: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing
#                 index  bil_pecahan  bil_bulat teks
# 0 2000-01-01 00:00:00          2.0          8    A
# 1 2000-01-01 01:00:00         10.0         12    B
# 2 2000-01-01 02:00:00         14.0         18    C
# 3 2000-01-01 03:00:00          4.0         19    D
# 4 2000-01-01 04:00:00         14.0          1    E

# %%
df.dtypes
# Out:
# index          datetime64[ns]
# bil_pecahan           float64
# bil_bulat               int32
# teks                   object
# dtype: object

# %%
df.select_dtypes(include='number')
# Out:
#    bil_pecahan  bil_bulat
# 0          2.0          8
# 1         10.0         12
# 2         14.0         18
# 3          4.0         19
# 4         14.0          1

# %%
df.select_dtypes(include='float')
# Out:
#    bil_pecahan
# 0          2.0
# 1         10.0
# 2         14.0
# 3          4.0
# 4         14.0

# %%
df.select_dtypes(include='int')
# Out:
#    bil_bulat
# 0          8
# 1         12
# 2         18
# 3         19
# 4          1

# %%
df.select_dtypes(include='object')
# Out:
#   teks
# 0    A
# 1    B
# 2    C
# 3    D
# 4    E

# %%
df.select_dtypes(include='datetime')
# Out:
#                 index
# 0 2000-01-01 00:00:00
# 1 2000-01-01 01:00:00
# 2 2000-01-01 02:00:00
# 3 2000-01-01 03:00:00
# 4 2000-01-01 04:00:00

# %%
df.select_dtypes(include=['number', 'object'])
# Out:
#    bil_pecahan  bil_bulat teks
# 0          2.0          8    A
# 1         10.0         12    B
# 2         14.0         18    C
# 3          4.0         19    D
# 4         14.0          1    E

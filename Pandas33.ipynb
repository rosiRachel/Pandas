# %% [markdown]
# Menampilkan niali kumulatif (cummulative)

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.3.4

# %% [markdown]
# Data Frame

# %%
d = {'Pemain':['Budi', 'Joni', 'Iwan', 'Budi', 'Budi', 'Iwan', 'Asep', 'Joni'],
    'Goal':[2, 1, 3, 1, 1, 2, 2, 3]}
df = pd.DataFrame(d)
df
# Out:
#   Pemain  Goal
# 0   Budi     2
# 1   Joni     1
# 2   Iwan     3
# 3   Budi     1
# 4   Budi     1
# 5   Iwan     2
# 6   Asep     2
# 7   Joni     3

# %% [markdown]
# Menampilkan niali kumulatif (cummulative)
# - cumprod (cummulative produk) : hasil perkalian

# %%
df['Goal'].cumsum().to_frame()
# Out:
#    Goal
# 0     2
# 1     3
# 2     6
# 3     7
# 4     8
# 5    10
# 6    12
# 7    15

# %%
df['Jumlah_goal_kumulatif'] = df['Goal'].cumsum()
df
# Out:
#   Pemain  Goal  Jumlah_goal_kumulatif
# 0   Budi     2                      2
# 1   Joni     1                      3
# 2   Iwan     3                      6
# 3   Budi     1                      7
# 4   Budi     1                      8
# 5   Iwan     2                     10
# 6   Asep     2                     12
# 7   Joni     3                     15

# %%
df['Jumlah_goal_kumulatif_tiap_pemain'] = df.groupby('Pemain')['Goal'].cumsum()
df
# Out:
#   Pemain  Goal  Jumlah_goal_kumulatif  Jumlah_goal_kumulatif_tiap_pemain
# 0   Budi     2                      2                                  2
# 1   Joni     1                      3                                  1
# 2   Iwan     3                      6                                  3
# 3   Budi     1                      7                                  3
# 4   Budi     1                      8                                  4
# 5   Iwan     2                     10                                  5
# 6   Asep     2                     12                                  2
# 7   Joni     3                     15                                  4

# %%
df['Cummax'] = df['Goal'].cummax()
df
# Out:
#   Pemain  Goal  Jumlah_goal_kumulatif  Jumlah_goal_kumulatif_tiap_pemain  \
# 0   Budi     2                      2                                  2
# 1   Joni     1                      3                                  1
# 2   Iwan     3                      6                                  3
# 3   Budi     1                      7                                  3
# 4   Budi     1                      8                                  4
# 5   Iwan     2                     10                                  5
# 6   Asep     2                     12                                  2
# 7   Joni     3                     15                                  4
#
#    Cummax
# 0       2
# 1       2
# 2       3
# 3       3
# 4       3
# 5       3
# 6       3
# 7       3

# %%
df['Cummin'] = df['Goal'].cummin()
df
# Out:
#   Pemain  Goal  Jumlah_goal_kumulatif  Jumlah_goal_kumulatif_tiap_pemain  \
# 0   Budi     2                      2                                  2
# 1   Joni     1                      3                                  1
# 2   Iwan     3                      6                                  3
# 3   Budi     1                      7                                  3
# 4   Budi     1                      8                                  4
# 5   Iwan     2                     10                                  5
# 6   Asep     2                     12                                  2
# 7   Joni     3                     15                                  4
#
#    Cummax  Cummin
# 0       2       2
# 1       2       1
# 2       3       1
# 3       3       1
# 4       3       1
# 5       3       1
# 6       3       1
# 7       3       1

# %%
df['Cumprod'] = df['Goal'].cumprod()
df
# Out:
#   Pemain  Goal  Jumlah_goal_kumulatif  Jumlah_goal_kumulatif_tiap_pemain  \
# 0   Budi     2                      2                                  2
# 1   Joni     1                      3                                  1
# 2   Iwan     3                      6                                  3
# 3   Budi     1                      7                                  3
# 4   Budi     1                      8                                  4
# 5   Iwan     2                     10                                  5
# 6   Asep     2                     12                                  2
# 7   Joni     3                     15                                  4
#
#    Cummax  Cummin  Cumprod
# 0       2       2        2
# 1       2       1        2
# 2       3       1        6
# 3       3       1        6
# 4       3       1        6
# 5       3       1       12
# 6       3       1       24
# 7       3       1       72
